# %% [markdown]
# # Recommendation system

# %%
# !pip install -qq convokit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.2/183.2 kB 3.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 32.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 35.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 27.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.3 MB/s eta 0:00:00
#   Building wheel for convokit (pyproject.toml) ... done
#   Building wheel for emoji (setup.py) ... done

# %%
# !pip install -qq scikit-surprise
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-surprise (setup.py) ... done

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
import convokit

# %%
# Load the Cornell Movie Dialogs Corpus
corpus = convokit.Corpus(filename=convokit.download("movie-corpus"))
# Out:
# Downloading movie-corpus to /root/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done
# No configuration file found at /root/.convokit/config.yml; writing with contents:
# # Default Backend Parameters
# db_host: localhost:27017
# data_directory: ~/.convokit/saved-corpora
# default_backend: mem

# %%
# Display basic statistics
print("Number of conversations:", len(corpus.conversations))
print("Number of users:", len(corpus.speakers))
print("Number of utterances:", len(corpus.utterances))
# Out:
# Number of conversations: 83097
# Number of users: 9035
# Number of utterances: 304713

# %%
# Display information about conversations
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)
    print("Conversation ID:", convo_id)
    print("Metadata:", convo.meta)
    print("Number of utterances in conversation:", len(convo.get_utterance_ids()))
    print()
# Out:
# Streaming output truncated to the last 5000 lines.
# Number of utterances in conversation: 3
#
# Conversation ID: L349479
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349475
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349256
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349249
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L349240
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L349217
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L349211
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L349209
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349207
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349896
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349651
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L349527
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L350000
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348925
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348923
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348917
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348912
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348909
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349918
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349910
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349907
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349425
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349421
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349407
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L349405
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349014
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349011
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349005
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L349001
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L348998
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348994
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L348988
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L348983
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L348978
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L348971
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L349884
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349471
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349349
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349344
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349319
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L349314
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L349835
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349128
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348855
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L349107
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349102
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L349979
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349878
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L349875
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349870
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349864
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349860
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349856
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349797
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349588
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349579
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L349567
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L349563
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349553
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L349550
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349523
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349454
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349452
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349444
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349442
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349440
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349432
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L349414
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349355
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L349353
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349312
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349307
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349301
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L349296
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349265
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L349263
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349260
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349235
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349227
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349202
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349180
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L349171
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349167
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349163
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349153
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349145
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L349048
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349046
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349042
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349039
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349037
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349035
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349914
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349889
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349351
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349341
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349338
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348931
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348927
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L348921
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349820
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L349595
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349853
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349845
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349801
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349799
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349791
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349779
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L349693
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349690
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349680
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L349676
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349674
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349671
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349668
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349545
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349539
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349535
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349508
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349503
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L349501
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349499
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349497
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349400
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349397
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349394
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349386
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L349294
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349291
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349286
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L349280
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349273
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L349271
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349174
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349169
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349155
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L349100
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349089
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L349070
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 19
#
# Conversation ID: L349061
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L349059
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349055
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L348953
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348951
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348940
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348938
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348936
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349814
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349376
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349371
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349332
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L348884
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L350013
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L350009
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349997
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349990
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349709
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349703
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L349700
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349627
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349620
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L349616
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349614
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349612
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349609
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349607
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349366
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349363
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349326
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348867
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L350026
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L350024
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348874
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348872
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348870
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349986
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L349965
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349961
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L350034
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L349793
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349754
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348960
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349758
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349661
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349601
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L349533
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349468
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349462
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L349458
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348877
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348848
# Metadata: ConvoKitMeta({'movie_idx': 'm119', 'movie_name': 'life as a house', 'release_year': '2001', 'rating': '7.50', 'votes': '19468', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348408
# Metadata: ConvoKitMeta({'movie_idx': 'm120', 'movie_name': 'the life of david gale', 'release_year': '2003', 'rating': '7.30', 'votes': '38237', 'genre': "['drama', 'crime', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348401
# Metadata: ConvoKitMeta({'movie_idx': 'm120', 'movie_name': 'the life of david gale', 'release_year': '2003', 'rating': '7.30', 'votes': '38237', 'genre': "['drama', 'crime', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L348522
# Metadata: ConvoKitMeta({'movie_idx': 'm120', 'movie_name': 'the life of david gale', 'release_year': '2003', 'rating': '7.30', 'votes': '38237', 'genre': "['drama', 'crime', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L348561
# Metadata: ConvoKitMeta({'movie_idx': 'm120', 'movie_name': 'the life of david gale', 'release_year': '2003', 'rating': '7.30', 'votes': '38237', 'genre': "['drama', 'crime', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348557
# Metadata: ConvoKitMeta({'movie_idx': 'm120', 'movie_name': 'the life of david gale', 'release_year': '2003', 'rating': '7.30', 'votes': '38237', 'genre': "['drama', 'crime', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348555
# Metadata: ConvoKitMeta({'movie_idx': 'm120', 'movie_name': 'the life of david gale', 'release_year': '2003', 'rating': '7.30', 'votes': '38237', 'genre': "['drama', 'crime', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L348242
# Metadata: ConvoKitMeta({'movie_idx': 'm120', 'movie_name': 'the life of david gale', 'release_year': '2003', 'rating': '7.30', 'votes': '38237', 'genre': "['drama', 'crime', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L348579
# Metadata: ConvoKitMeta({'movie_idx': 'm120', 'movie_name': 'the life of david gale', 'release_year': '2003', 'rating': '7.30', 'votes': '38237', 'genre': "['drama', 'crime', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L348573
# Metadata: ConvoKitMeta({'movie_idx': 'm120', 'movie_name': 'the life of david gale', 'release_year': '2003', 'rating': '7.30', 'votes': '38237', 'genre': "['drama', 'crime', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L348500
# ...
# Number of utterances in conversation: 6
#
# Conversation ID: L666019
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665957
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665904
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665896
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665891
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665873
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665868
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665865
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665861
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665840
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665802
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665798
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665775
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665755
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665748
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L665691
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665676
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665663
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665658
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665636
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665627
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L665623
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665615
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L665564
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665558
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665552
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665548
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666168
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666166
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666160
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666158
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666151
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666149
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665949
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665900
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665885
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665694
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665651
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665994
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665992
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665987
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L666462
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666365
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666361
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666503
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666388
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L666487
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666483
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666480
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666357
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666249
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666246
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666546
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666485
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666460
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666383
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666251
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666497
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666575
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666324
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666262
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666520
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666369
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666256
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2

# %%
# Create empty lists to store data
conversation_ids = []
movie_indices = []
movie_names = []
release_years = []
ratings = []
votes = []
genres = []
num_utterances = []

# Loop through conversations and extract data
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)

    # Extract metadata from ConvoKitMeta object
    metadata = convo.meta

    # Append data to respective lists
    conversation_ids.append(convo_id)
    movie_indices.append(metadata['movie_idx'])
    movie_names.append(metadata['movie_name'])
    release_years.append(metadata['release_year'])
    ratings.append(metadata['rating'])
    votes.append(metadata['votes'])
    genres.append(metadata['genre'])
    num_utterances.append(len(convo.get_utterance_ids()))

# Create a DataFrame from the lists
data = {
    'Conversation ID': conversation_ids,
    'Movie Index': movie_indices,
    'Movie Name': movie_names,
    'Rating': ratings,
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       Conversation ID Movie Index                  Movie Name Rating
# 0               L1044          m0  10 things i hate about you   6.90
# 1                L984          m0  10 things i hate about you   6.90
# 2                L924          m0  10 things i hate about you   6.90
# 3                L870          m0  10 things i hate about you   6.90
# 4                L866          m0  10 things i hate about you   6.90
# ...               ...         ...                         ...    ...
# 83092         L666324        m616                   zulu dawn   6.40
# 83093         L666262        m616                   zulu dawn   6.40
# 83094         L666520        m616                   zulu dawn   6.40
# 83095         L666369        m616                   zulu dawn   6.40
# 83096         L666256        m616                   zulu dawn   6.40
#
# [83097 rows x 4 columns]

# %%
# Create a Reader object specifying the rating scale
reader = Reader(rating_scale=(1, 10))

# %%
# Load the dataset into Surprise format
data = df[['Conversation ID','Movie Name','Rating']]
data = Dataset.load_from_df(data, reader)

# Split the data into training and testing sets (80% train, 20% test)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# Create and train the SVD recommendation model
model = SVD()
model.fit(trainset)

# Evaluate the model on the testing data (calculate RMSE)
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.0632

# %%
# Generate recommendations for a specific user (e.g., user_id='L236416')
user_id = 'L36547'
user_movies = df[df['Conversation ID'] == user_id]['Movie Name'].unique()

# Create a list of unrated movies for the user
all_movies = df['Movie Name'].unique()
unrated_movies = np.setdiff1d(all_movies, user_movies)

# Generate predictions for unrated movies
user_recommendations = []
for movie_id in unrated_movies:
    predicted_rating = model.predict(user_id, movie_id).est
    user_recommendations.append((movie_id, predicted_rating))

    # Sort recommendations by predicted rating (highest first)
user_recommendations.sort(key=lambda x: x[1], reverse=True)

# %%
# Display the top n recommendations
top_n = 3
print(f'Top {top_n} recommendations for user {user_id}:')
for movie_id, predicted_rating in user_recommendations[:top_n]:
    print(f'Movie ID: {movie_id}, Predicted Rating: {predicted_rating:.2f}')
# Out:
# Top 3 recommendations for user L36547:
# Movie ID: neuromancer, Predicted Rating: 9.20
# Movie ID: the godfather, Predicted Rating: 9.14
# Movie ID: the godfather: part ii, Predicted Rating: 8.89
